), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75665174481342, 16.583070486060205]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.73905645367573, 16.57303441554621]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.73897062298725, 16.576160460837343]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75863085888989, 16.541956983023095]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75605593823559, 16.540311410309474]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75391017102368, 16.543355708792998]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75176440381176, 16.545494916822438]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.74738703869946, 16.544589870167083]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.75279437207348, 16.547963204295677]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.76832972668774, 16.54434303852401]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.76721392773754, 16.54557719358051]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.82248889111645, 16.564211974663042]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.82188807629711, 16.565939611431574]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.81656657361157, 16.56565167304621]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.81630908154614, 16.566844557840426]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.83197318219311, 16.569970703627376]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.83124362134106, 16.569929570459642]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.83244525097973, 16.572233014320727]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.83270274304516, 16.57169828873752]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.49305418410191, 16.15337106573398]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.49309709944615, 16.152216872563404]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.50163725294956, 16.164253127342104]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.49992063918003, 16.165984309194453]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.50150850691685, 16.162398272818645]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.46493914787682, 16.16136828976099]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.46474602882775, 16.160337802137462]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.25822267006906, 16.555706884493485]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.16088463001036, 16.473013138089417]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.17307258777403, 16.482231373408172]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.20517326526426, 16.500831119119823]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.19950843982481, 16.503793745385142]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.18903709583067, 16.49671628513615]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.17324424915098, 16.497045475075826]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.22680259876036, 16.515808375428595]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.22130943469786, 16.514327160030426]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.08510522498582, 16.43106850481575]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.091800018687, 16.432879655749964]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.05781106605028, 16.449014618543156]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.0397866214702, 16.446874343479195]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.03704003943895, 16.440618019514403]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([81.04703931464647, 16.430121760107752]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.700796191098, 16.39694739444304]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.7234554928558, 16.366479260477185]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.73066527068784, 16.370432152072322]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.73839003265073, 16.360879193619002]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.78208467593247, 16.290438796447116]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.81882021060044, 16.271983740230105]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.81941745585313, 16.252289798625945]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.79675815409531, 16.24371993070341]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.8290304929625, 16.23350152315253]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.82559726542344, 16.20943672597745]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.85943902272568, 16.155806870742932]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.84295953053818, 16.165040059898843]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.8659621550499, 16.111613501603735]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.61981839864738, 16.5010537785084]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.6318346950341, 16.49282403249335]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.35648984640129, 16.59813829536048]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.34344358175285, 16.597480259969693]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.29908483391505, 16.599520733748772]), {'Class': 3,'Class_name': 'barren'}),
  ee.Feature(ee.Geometry.Point([80.18819158440333, 16.633077308260823]), {'Class': 3,'Class_name': 'barren'})
])




#Dataset for Andhra Pradesh
dataset = ee.FeatureCollection("FAO/GAUL/2015/level2")
andhraPradesh = dataset.filter(ee.Filter.eq('ADM1_NAME', 'Andhra Pradesh'))

# Define training region (Krishna & Guntur)
krishna = andhraPradesh.filter(ee.Filter.eq('ADM2_NAME', 'Krishna'))
guntur = andhraPradesh.filter(ee.Filter.eq('ADM2_NAME', 'Guntur'))
train_roi = krishna.merge(guntur)

# Define outline style for visualization
outline_style = {
    'color': 'black',
    'fillColor': '00000000',  # Transparent fill
    'width': 1
}

# Load training data and train classifier on Krishna & Guntur for 2020
bands = ['B8', 'B4', 'B3']
label = 'Class'

# Define sample training data (replace with actual training data)
# Assuming 'barren', 'buildup', 'water', 'vegetation' are actual FeatureCollections
training_data = barren.merge(buildup).merge(water).merge(vegetation)  # These should be actual FeatureCollections

train_image = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterDate('2020-01-01', '2020-12-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .filterBounds(train_roi) \
    .median()

train_image_sample = train_image.select(bands).sampleRegions(
    collection=training_data,
    properties=[label],
    scale=30
)

training_data = train_image_sample.randomColumn()
train_set = training_data.filter(ee.Filter.lessThan('random', 0.8))
classifier = ee.Classifier.smileCart().train(train_set, label, bands)

# Function to get median image for a given year
def get_median_image(year, roi):
    return ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
        .filterDate(f'{year}-01-01', f'{year}-12-31') \
        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
        .filterBounds(roi) \
        .median()

# Function to classify image for a given year and district
def classify_image(image, roi):
    input_image = image.select(bands)
    classified = input_image.classify(classifier).clip(roi)
    return classified

# Function to classify image for a given year and district
class_names = ['Water', 'Buildup', 'Vegetation', 'Barren']

# Function to extract and display area for each class
def extract_class_areas_optimized(classified_image, roi, year):
    classes = [0, 1, 2, 3]  # Adjust based on the actual classes used in classification
    areas = []
    print(f"Class areas in square kilometers for {year}:")

    for class_id in classes:
        class_mask = classified_image.eq(class_id)
        area = class_mask.multiply(ee.Image.pixelArea()).reduceRegion(
            reducer=ee.Reducer.sum(),
            geometry=roi,
            scale=100,
            maxPixels=1e9
        ).get('classification')

        area_km2 = ee.Number(area).divide(1e6) if area else ee.Number(0)
        areas.append((class_names[class_id], round(area_km2.getInfo(), 2)))

    area_df = pd.DataFrame(areas, columns=['Class', 'Area (km²)'])
    print(area_df)

    return area_df


# Function to classify district and display map
def classify_district(year1, year2, district_name):
    roi = andhraPradesh.filter(ee.Filter.eq('ADM2_NAME', district_name))

    if roi.size().getInfo() == 0:
        return None, f"Error: District '{district_name}' not found."

    imageYear1 = get_median_image(year1, roi)
    imageYear2 = get_median_image(year2, roi)

    classifiedYear1 = classify_image(imageYear1, roi)
    classifiedYear2 = classify_image(imageYear2, roi)

    Map = geemap.Map()
    Map.centerObject(roi, 9)
    palette = ['253494', 'd43333', '19cc00', 'd68b0a']
    Map.addLayer(roi.style(**outline_style), {}, f'{district_name} Border')
    Map.addLayer(classifiedYear1, {'palette': palette, 'min': 0, 'max': 3}, f'Classification {year1}')
    Map.addLayer(classifiedYear2, {'palette': palette, 'min': 0, 'max': 3}, f'Classification {year2}')
    legend_labels = ['Water', 'Buildup', 'Vegetation', 'Barren']  # Update these with your actual class names
    legend_colors = palette  # Using the palette defined above

    # Add a custom legend to the map
    Map.add_legend(title="Land Cover Classification", legend_dict={label: color for label, color in zip(legend_labels, legend_colors)})
    return Map, classifiedYear1, classifiedYear2, roi

# Streamlit interface
st.title("Land Cover Classification for Andhra Pradesh")
st.write("Select two years and a district to view the land cover classification.")

# District list
district_list = [
    "Anantapur", "Chittoor", "Cuddapah", "East Godavari", "Guntur", "Krishna",
    "Kurnool", "Nellore", "Prakasam", "Srikakulam", "Vishakhapatnam", "Vizianagaram",
    "West Godavari"
]


# User inputs
year1 = st.selectbox("Select Year 1", ["2018", "2019", "2020", "2021","2022","2023"])
year2 = st.selectbox("Select Year 2", ["2018", "2019", "2020", "2021","2022","2023"])
district_name = st.selectbox("Select District", district_list)

# Button to trigger the classification and map display
if st.button("Show Classification"):
    map_result, classifiedYear1, classifiedYear2 ,roi= classify_district(year1, year2, district_name)
    map_result.to_streamlit(height=500)

    # Extract area data for both years
    area_year1_df = extract_class_areas_optimized(classifiedYear1, roi, year1)
    area_year2_df = extract_class_areas_optimized(classifiedYear2, roi, year2)

    # Combine the data for display
    combined_df = area_year1_df.merge(area_year2_df, on='Class', suffixes=(f'_{year1}', f'_{year2}'))
    st.write(combined_df)

    # Create a bar plot for the area comparison
    st.subheader(f'Land Cover Area Comparison ({year1} vs {year2})')
    plt.figure(figsize=(10, 6))
    bar_width = 0.35
    index = range(len(combined_df))
    bar1 = plt.bar(index, combined_df[f'Area (km²)_{year1}'], bar_width, label=f'{year1}', color='b')
    bar2 = plt.bar([i + bar_width for i in index], combined_df[f'Area (km²)_{year2}'], bar_width, label=f'{year2}', color='g')
    plt.xlabel('Land Cover Class')
    plt.ylabel('Area (km²)')
    plt.xticks([i + bar_width / 2 for i in index], combined_df['Class'], rotation=45)
    plt.legend()
    plt.tight_layout()
    st.pyplot(plt)  # Display the area comparison plot in Streamlit

    # Create and show the legend for land cover changes
    st.subheader(f'Land Cover Change Legend ({year1} vs {year2})')
    def calculate_change(classified_image_year1, classified_image_year2):
    # Calculate the difference between two classified images (change detection)
      change_image = classified_image_year1.subtract(classified_image_year2).clip(roi)
      return change_image

    # Calculate changes between the two years dynamically
    change_image = calculate_change(classifiedYear1, classifiedYear2)
    # Show the change map
    change_palette = [
    'FFFFFF', 'FF0000', '00FF00', '0000FF', 'FFFF00', 'FF00FF', '00FFFF', 'F0F0F0', '000000', 'C0C0C0', '8B0000', '008B00', '00008B'
    ]
    # Create the map
    Map4 = geemap.Map()

    # Add the change image layer to the map with the specified palette and min/max values
    Map4.addLayer(change_image, {'palette': change_palette, 'min': 0, 'max': 12}, f'Land Cover Change ({year1} to {year2})')

    # Center the map on the region of interest (ROI) with appropriate zoom level
    Map4.centerObject(roi, 9)

    # Add layer control to the map
    Map4.addLayerControl()

    # Define the legend labels and their corresponding colors
    legend_labels = [
        'No Change',
        'Water to Buildup',
        'Water to Vegetation',
        'Water to Barren',
        'Buildup to Water',
        'Buildup to Vegetation',
        'Buildup to Barren',
        'Vegetation to Water',
        'Vegetation to Buildup',
        'Vegetation to Barren',
        'Barren to Water',
        'Barren to Buildup',
        'Barren to Vegetation'
    ]

    # Add the custom legend to the map
    Map4.add_legend(title="Land Cover Change", legend_dict={label: color for label, color in zip(legend_labels, change_palette)})
    Map4.to_streamlit(height=500)  # Display the change map in Streamlit
"""

# Write code to app.py
with open("app.py", "w") as file:
    file.write(code)

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.139.34.226

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.139.34.226:8501
#
# ⠙⠹⠸⠼⠴⠦⠧Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴your url is: https://easy-buckets-sneeze.loca.lt
# Class areas in square kilometers for 2018:
#         Class  Area (km²)
# 0       Water      204.17
# 1     Buildup     3117.16
# 2  Vegetation     1875.12
# 3      Barren    14029.93
# Class areas in square kilometers for 2021:
#         Class  Area (km²)
# 0       Water      383.79
# 1     Buildup     1763.99
# 2  Vegetation     4182.15
# 3      Barren    12896.45
